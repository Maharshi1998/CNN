# %% [markdown]
# ## Perform standard imports

# %%
! pip install split-folders
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
import splitfolders
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use('dark_background')

# %% [markdown]
# # Check GPU

# %%
print('GPU name: ', tf.config.experimental.list_physical_devices('GPU'))
# Out:
# GPU name:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
            logical_gpus = tf.config.experimental.list_logical_devices('GPU')
            print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/12. Convolutional Neural Network (CNN)
# Out:
# /content/drive/MyDrive/12. Convolutional Neural Network (CNN)

# %% [markdown]
# ## Prepare train and test sets, loaders

# %%
splitfolders.ratio("Circle_Cross", output="TrainTest",
    seed=1337, ratio=(.8, .2), group_prefix=None, move=False) # default values
# Out:
# Copying files: 2011 files [00:43, 45.90 files/s]

# %% [markdown]
# # Creating train and test data generators

# %%
train_datagen = ImageDataGenerator(rescale = 1./255)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
num_classes = 2
img_shape = (116,116,3)
batch_size = 32

# %% [markdown]
# ## Creating Training and Testing Datasets

# %%
training_set = train_datagen.flow_from_directory('TrainTest/train',
                                                 target_size = (116,116),
                                                 class_mode='binary',
                                                 shuffle = True,
                                                 batch_size = batch_size)
# Out:
# Found 1607 images belonging to 2 classes.

# %%
test_set = train_datagen.flow_from_directory('TrainTest/val',
                                                 target_size = (116,116),
                                                 class_mode='binary',
                                                 shuffle = False,
                                                 batch_size = batch_size)
# Out:
# Found 403 images belonging to 2 classes.

# %% [markdown]
# ##  Create CNN

# %%
model = Sequential()
model.add(Conv2D(10 ,kernel_size = (5, 5), padding = 'SAME', input_shape = img_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2),strides = 2))

model.add(Conv2D(20, (5, 5), padding='SAME')) # "SAME" tries to pad evenly left and right
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2),strides = 2))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 116, 116, 10)      760
#
#  activation (Activation)     (None, 116, 116, 10)      0
#
#  max_pooling2d (MaxPooling2  (None, 58, 58, 10)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 58, 58, 20)        5020
#
#  activation_1 (Activation)   (None, 58, 58, 20)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 29, 29, 20)        0
#  g2D)
#
#  flatten (Flatten)           (None, 16820)             0
#
#  dense (Dense)               (None, 64)                1076544
#
#  activation_2 (Activation)   (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
#  activation_3 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 1082389 (4.13 MB)
# Trainable params: 1082389 (4.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Training and Testing the model

# %%
model.compile(optimizer = tf.keras.optimizers.SGD(learning_rate = 0.01, momentum = 0.9) ,
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
hist = model.fit(training_set,
                              epochs = 41,
                              validation_data = test_set)
# Out:
# Epoch 1/41
# 51/51 [==============================] - 14s 161ms/step - loss: 0.5750 - accuracy: 0.7405 - val_loss: 0.1664 - val_accuracy: 0.9404
# Epoch 2/41
# 51/51 [==============================] - 4s 86ms/step - loss: 0.0773 - accuracy: 0.9801 - val_loss: 0.0351 - val_accuracy: 0.9901
# Epoch 3/41
# 51/51 [==============================] - 3s 64ms/step - loss: 0.0269 - accuracy: 0.9938 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 4/41
# 51/51 [==============================] - 3s 60ms/step - loss: 0.0125 - accuracy: 0.9981 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 5/41
# 51/51 [==============================] - 3s 63ms/step - loss: 0.0086 - accuracy: 0.9975 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 6/41
# 51/51 [==============================] - 3s 66ms/step - loss: 0.0037 - accuracy: 0.9994 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 7/41
# 51/51 [==============================] - 3s 61ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 8/41
# 51/51 [==============================] - 3s 62ms/step - loss: 5.9087e-04 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch
# 51/51 [==============================] - 3s 64ms/step - loss: 4.9497e-05 - accuracy: 1.0000 - val_loss: 9.1160e-04 - val_accuracy: 1.0000
# Epoch 32/41
# 51/51 [==============================] - 4s 85ms/step - loss: 4.7449e-05 - accuracy: 1.0000 - val_loss: 9.3055e-04 - val_accuracy: 1.0000
# Epoch 33/41
# 51/51 [==============================] - 8s 165ms/step - loss: 4.5436e-05 - accuracy: 1.0000 - val_loss: 8.2317e-04 - val_accuracy: 1.0000
# Epoch 34/41
# 51/51 [==============================] - 4s 70ms/step - loss: 4.3953e-05 - accuracy: 1.0000 - val_loss: 8.5235e-04 - val_accuracy: 1.0000
# Epoch 35/41
# 51/51 [==============================] - 3s 64ms/step - loss: 4.1863e-05 - accuracy: 1.0000 - val_loss: 8.2341e-04 - val_accuracy: 1.0000
# Epoch 36/41
# 51/51 [==============================] - 3s 65ms/step - loss: 4.0367e-05 - accuracy: 1.0000 - val_loss: 8.4336e-04 - val_accuracy: 1.0000
# Epoch 37/41
# 51/51 [==============================] - 3s 68ms/step - loss: 3.9191e-05 - accuracy: 1.0000 - val_loss: 8.4123e-04 - val_accuracy: 1.0000
# Epoch 38/41
# 51/51 [==============================] - 3s 64ms/step - loss: 3.7720e-05 - accuracy: 1.0000 - val_loss: 7.9242e-04 - val_accuracy: 1.0000
# Epoch 39/41
# 51/51 [==============================] - 3s 63ms/step - loss: 3.6443e-05 - accuracy: 1.0000 - val_loss: 8.6928e-04 - val_accuracy: 1.0000
# Epoch 40/41
# 51/51 [==============================] - 4s 74ms/step - loss: 3.5076e-05 - accuracy: 1.0000 - val_loss: 8.1504e-04 - val_accuracy: 1.0000
# Epoch 41/41
# 51/51 [==============================] - 3s 64ms/step - loss: 3.4202e-05 - accuracy: 1.0000 - val_loss: 7.9721e-04 - val_accuracy: 1.0000

# %%
trainAcc = [100 * x for x in hist.history['accuracy']]
testAcc = [100 * x for x in hist.history['val_accuracy']]

# %%
fig,ax = plt.subplots(1,2,figsize=(18,6))

ax[0].plot(hist.history['loss'], 'g', lw = 3, label = 'Train')
ax[0].set_xlabel('Epochs', fontsize = 15)
ax[0].set_ylabel('Loss', fontsize = 15)
ax[0].legend(fontsize = 15)
ax[0].set_title('Training Loss', fontsize = 15)


ax[1].plot(trainAcc, label ='Train', lw = 3)
ax[1].plot(testAcc, label ='Test', lw = 3)
ax[1].set_xlabel('Epochs', fontsize = 15)
ax[1].set_ylabel('Accuracy (%)', fontsize = 15)
ax[1].set_ylim([10,110])
ax[1].set_title(f'Train Accuracy: {trainAcc[-1]:.2f}% \n Test Accuracy: {testAcc[-1]:.2f}%', fontsize = 15)
ax[1].legend(fontsize = 15)

plt.show()
